# %% [markdown]
# # Variables in Python
# - Variables acts as a container to store data in memory space.
# - Variables are pointer towards object in python
# - Variables can start with letters or underscore.
# - You cannot include special characters while creating a variable.
#
# **Important points to remeber while creating a variable**
# 1. Python is case sensitive
# 2. If variable name involves more than 2 words, join those words with underscore.
# 3. Give meaningful name to variables

# %%
#variable
10
# Out:
# 10

# %%
a = 10

# %%
id(a)
# Out:
# 2039799769680

# %%
2name = 'Python'
# Out:
#   File "C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_33572\2076040130.py", line 1
#     2name = 'Python'
#      ^
# SyntaxError: invalid syntax

# %%
name2 = 'Python'
name2
# Out:
# 'Python'

# %%
@name = 20
# Out:
#   File "C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_33572\3299916095.py", line 1
#     @name = 20
#           ^
# SyntaxError: invalid syntax

# %%
_ten = 10

# %%
_ten
# Out:
# 10

# %%
#Single line comment

# %%
age = 60 #age variable contains 60 value.
age
# Out:
# 60

# %%
#Multi-line comment
'''This is first line 
This is second line 
This is third line'''
# Out:
# 'This is first line \nThis is second line \nThis is third line'

# %%
age
# Out:
# 60

# %%
print('My age is',age)
# Out:
# My age is 60

# %% [markdown]
# # Operators in Python
#
# 1. Arithmetic operators (+,-,*,/,%)
# 2. Comparison operators (==,!=,<,>, <=,>=)
# 3. Logical operators (and, or)
# 4. Identity operators (is, is not)
# 5. Membership Operators (in, not in)

# %% [markdown]
# - Arithmetic Operators

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
num1 = 25632
num2 = 12

# %%
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1/num2)
print(num1%num2)
# Out:
# 25644
# 25620
# 307584
# 2136.0
# 0

# %% [markdown]
# **Comparison Operators**

# %%
a = 85
b = 75

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
a < b
# Out:
# False

# %%
a <= b
# Out:
# False

# %% [markdown]
# **Logical Operators**

# %%
x = 10
y = 20

# %%
x > y and x > 5
# Out:
# False

# %%
x < y and x > 5
# Out:
# True

# %%
x > y or x > 5
# Out:
# True

# %% [markdown]
# **Identity Operators**

# %%
x,y
# Out:
# (10, 20)

# %%
x is y
# Out:
# False

# %%
x is not y
# Out:
# True

# %% [markdown]
# **Membership Operators**

# %%
course = 'Data Science'

# %%
'S' in course
# Out:
# True

# %%
's' in course
# Out:
# False

# %%
' ' in course
# Out:
# True

# %%
'Data' in course
# Out:
# True

# %%
'y' not in course
# Out:
# True

# %% [markdown]
# # Data types in python
# 1. Integer
# 2. Float
# 3. String
# 4. Boolean

# %%
#Integer
pin_code = 455156 
pin_code
# Out:
# 455156

# %%
type(pin_code)
# Out:
# int

# %%
temp = 25.2
type(temp)
# Out:
# float

# %%
logical = True
type(logical)
# Out:
# bool

# %%
#String creation

# %%
s = 'We are learning python'
s1 = "We are learning python"
s2 = '''We are learning python'''

# %%
s==s1
# Out:
# True

# %%
s==s2
# Out:
# True

# %%
st = 'It's a laptop'
# Out:
#   File "C:\Users\Aishwarya\AppData\Local\Temp\ipykernel_33572\3600212398.py", line 1
#     st = 'It's a laptop'
#              ^
# SyntaxError: invalid syntax

# %%
st = "It's a laptop"
st
# Out:
# "It's a laptop"

# %%
st1 = 'It"s a laptop'
st1
# Out:
# 'It"s a laptop'

# %% [markdown]
# # Typecasting
#
# - Typecasting is used to change the data types.

# %%
age
type(age)
# Out:
# int

# %%
x = str(age)
type(x)
# Out:
# str

# %%
int(x)
# Out:
# 60

# %%
float(age)
# Out:
# 60.0

# %%
age
# Out:
# 60

# %%
bool(-5)
# Out:
# True

# %%
zero = 0

bool(zero)
# Out:
# False

# %%
#We can convert any type of values to bool type, and the output for all values will be True , 
#Except 0, which is False

# %% [markdown]
# # String methods

# %%
#Create a string
s
# Out:
# 'We are learning python'

# %%
#Capitalize function

# %%
s1 = 'we are learning python'
s1.capitalize()
# Out:
# 'We are learning python'

# %%
s.capitalize()
# Out:
# 'We are learning python'

# %%
#Count

# %%
s.count('a')
# Out:
# 2

# %%
# Starts with and endswith function

# %%
s
# Out:
# 'We are learning python'

# %%
s.startswith('we')
# Out:
# False

# %%
s.endswith('n')
# Out:
# True

# %%
s.endswith('N')
# Out:
# False

# %%
#Find

# %%
s
# Out:
# 'We are learning python'

# %%
s.find('learning')
# Out:
# 7

# %%
s.find('We')
# Out:
# 0

# %%
#Replace

# %%
s
# Out:
# 'We are learning python'

# %%
s.replace('We','They')
# Out:
# 'They are learning python'

# %%
s
# Out:
# 'We are learning python'

# %%
s = s.replace('We','They')

# %%
s
# Out:
# 'They are learning python'

# %%
#Split

# %%
s
# Out:
# 'They are learning python'

# %%
s[0:4] = 'We'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33572\3103857364.py in <module>
# ----> 1 s[0:4] = 'We'
#
# TypeError: 'str' object does not support item assignment

# %%
len(s)
# Out:
# 24

# %%
s
# Out:
# 'They are learning python'

# %%
s.split(' ')
# Out:
# ['They', 'are', 'learning', 'python']

# %%
s2 = 'Theyare learningpython'
s2
# Out:
# 'They are learning python'

# %%
s2.split()
# Out:
# ['They', 'are', 'learning', 'python']

# %%
#Basic functions

# %%
s.upper()
# Out:
# 'THEY ARE LEARNING PYTHON'

# %%
s.lower()
# Out:
# 'they are learning python'

# %%
s.swapcase()
# Out:
# 'tHEY ARE LEARNING PYTHON'

# %%
s1 = 'rohit'
s2 = 'rohit'

s1
# Out:
# 'rohit'

# %%
#Join

s

'*'.join(s)
# Out:
# 'T*h*e*y* *a*r*e* *l*e*a*r*n*i*n*g* *p*y*t*h*o*n'

# %%
email = 'abc@gmail.com'


email.split('@')
# Out:
# ['abc', 'gmail.com']

# %%
s.title()
# Out:
# 'They Are Learning Python'

# %%
s.capitalize()
# Out:
# 'They are learning python'

# %% [markdown]
# # Data Structures
# 1. Lists
# 2. Tuple
# 3. Dictionary
# 4. Sets

# %% [markdown]
# **Lists**
#
# - Lists are the built in data structures in python.
# - Lists are heterogenous data structure.
# - Lists are mutable.

# %%
#Creating lists

# %%
lst = []
type(lst)
# Out:
# list

# %%
lst = [10,10.2,True,'Python']
lst
# Out:
# [10, 10.2, True, 'Python']

# %%
lst
# Out:
# [10, 10.2, True, 'Python']

# %%
#append

# %%
lst.append(False)

# %%
lst
# Out:
# [10, 10.2, True, 'Python', False]

# %%
lst.append('R')

# %%
lst
# Out:
# [10, 10.2, True, 'Python', False, 'R', 'R']

# %%
#Count

# %%
lst.count('R')
# Out:
# 2

# %%
#Index
lst.index('Python')
# Out:
# 3

# %%
#Insert

# %%
lst.insert(0,1000)

# %%
lst
# Out:
# [1000, 10, 10.2, True, 'Python', False, 'R', 'R']

# %%
#pop

# %%
lst.pop()
# Out:
# 'R'

# %%
lst
# Out:
# [1000, 10, 10.2, True, 'Python', False]

# %%
#reverse

# %%
lst.reverse()

# %%
lst
# Out:
# [False, 'Python', True, 10.2, 10, 1000]

# %%
#remove

# %%
lst.remove(10.2)

# %%
lst
# Out:
# [False, 'Python', True, 10, 1000]

# %%
#Replacing elements in lists

# %%
lst
# Out:
# [False, 'Python', True, 10, 1000]

# %%
lst[3]
# Out:
# 10

# %%
lst[3] = 5.5

# %%
lst
# Out:
# [False, 'Python', True, 5.5, 1000]

# %% [markdown]
# **Tuple**
#
# - Tuples are ordered and heterogenous data structure.
# - Tuples are immutable.

# %%
#Create a tuple

# %%
t = ()
type(t)
# Out:
# tuple

# %%
t = (10,5.5,True,'python')
t
# Out:
# (10, 5.5, True, 'python')

# %%
t.count(5.5)
# Out:
# 1

# %%
t.index(True)
# Out:
# 2

# %%
#Accessing elements from tuple

# %%
t[3]
# Out:
# 'python'

# %% [markdown]
# **Dictionary**
#
# - Python dictionaries are ordered collection of items.
# - Dictionary is mutable data structure.
# - It has key and value pair.

# %%
#Creating an empty dictionary

# %%
dictionary = {}
type(dictionary)
# Out:
# dict

# %%
#Adding elements in a dictionary

# %%
dictionary = {
    'Name':'ABC',
    'Age' : 25,
    'Location' :'Pune',
    'Course': 'DS'
}

# %%
dictionary
# Out:
# {'Name': 'ABC', 'Age': 25, 'Location': 'Pune', 'Course': 'DS'}

# %%
#get

# %%
dictionary.get('Name')
# Out:
# 'ABC'

# %%
dictionary.get('Location')
# Out:
# 'Pune'

# %%
#items

# %%
dictionary.items()
# Out:
# dict_items([('Name', 'ABC'), ('Age', 25), ('Location', 'Pune'), ('Course', 'DS')])

# %%
#keys

# %%
dictionary.keys()
# Out:
# dict_keys(['Name', 'Age', 'Location', 'Course'])

# %%
#Adding values in dictionary(update)
dictionary.update({'Date':2023})

# %%
dictionary
# Out:
# {'Name': 'ABC', 'Age': 25, 'Location': 'Pune', 'Course': 'DS', 'Date': 2023}

# %%
dictionary.update({'Subject' : 'ML','Month':'July'})

# %%
dictionary
# Out:
# {'Name': 'ABC',
#  'Age': 25,
#  'Location': 'Pune',
#  'Course': 'DS',
#  'Date': 2023,
#  'Subject': 'ML',
#  'Month': 'July'}

# %%
dictionary['Name']
# Out:
# 'ABC'

# %%
dictionary['Name'] = 'XYZ'

# %%
dictionary
# Out:
# {'Name': 'XYZ',
#  'Age': 25,
#  'Location': 'Pune',
#  'Course': 'DS',
#  'Date': 2023,
#  'Subject': 'ML',
#  'Month': 'July'}

# %%
dictionary.pop('Subject')
# Out:
# 'ML'

# %%
dictionary
# Out:
# {'Name': 'XYZ',
#  'Age': 25,
#  'Location': 'Pune',
#  'Course': 'DS',
#  'Date': 2023,
#  'Month': 'July'}

# %%
#values

# %%
dictionary.values()
# Out:
# dict_values(['XYZ', 25, 'Pune', 'DS', 2023, 'July'])

# %% [markdown]
# **Set**
#
# - Set is a collection which is unordered,unindexed.
# - Set is immutable.
# - Sets are unordered, so you cannot be sure in which order the items will appear.
# - Sets do not allow duplicate values.
# - Once a set is created, you cannot change its items, but you can remove items and add new items.
# - As sets are unordered, they do not support indexing and slicing operations.

# %%
#creating an empty set
s = {10,20,True,'Hello'}
type(s)
# Out:
# set

# %%
#Does not allow duplicate items
s1 = {10,10,10,20,30,40,50}

# %%
s1
# Out:
# {10, 20, 30, 40, 50}

# %%
#Does not support indexing

# %%
s1[4]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_30492\3229368127.py in <module>
# ----> 1 s1[4]
#
# TypeError: 'set' object is not subscriptable

# %%
#Add
s1.add(60)

# %%
s1
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
#pop

# %%
s1.pop()
# Out:
# 50

# %%
s1
# Out:
# {10, 20, 30, 40, 60}

# %%
s1 = {'blue','red','green'}
s2 = {'yellow','orange','blue'}

# %%
s1.intersection(s2)
# Out:
# {'blue'}

# %%
s1.union(s2)
# Out:
# {'blue', 'green', 'orange', 'red', 'yellow'}

# %%
s1.difference(s2)
# Out:
# {'green', 'red'}

# %%
s2.difference(s1)
# Out:
# {'orange', 'yellow'}

# %%
s1,s2
# Out:
# ({'blue', 'green', 'red'}, {'blue', 'orange', 'yellow'})
